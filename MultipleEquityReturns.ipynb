# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import yfinance as yf
from yahoofinancials import YahooFinancials

# %%
# input information here

tickers = ["SPY", "TLT", "GLD"]
start_date = "2010-01-01"
end_date = "2021-01-01"

# %%
# pull data from Yahoo Finance

stocks = yf.download(tickers, start = start_date, end = end_date, auto_adjust = True)
stocks = stocks['Close']
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
# print returns

for ticker in tickers:
    print(ticker + ':', (stocks[ticker][-1]/stocks[ticker][0]-1) * 100)
# Out:
# SPY: 310.46284407166087
# TLT: 137.61205811327807
# GLD: 62.440797498225706

# %%
# plot returns on graph

stocks.plot(kind = 'line', figsize = (20,15))
# Out:
# <AxesSubplot:xlabel='Date'>
