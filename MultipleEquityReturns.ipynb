# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import yfinance as yf
from yahoofinancials import YahooFinancials

# %%
# input information here

tickers = ["SPY", "TLT", "GLD"]
start_date = "2010-01-01"
end_date = "2021-01-01"

# %%
# pull data from Yahoo Finance

stocks = yf.download(tickers, start = start_date, end = end_date, auto_adjust = True)
stocks = stocks['Close']
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
# print returns

for ticker in tickers:
    print(ticker + ':', round((stocks[ticker][-1]/stocks[ticker][0]-1) * 100, 2), '%')
# Out:
# SPY: 310.46 %
# TLT: 137.61 %
# GLD: 62.44 %

# %%
# plot stock price on graph

stocks.plot(kind = 'line', figsize = (20,15), title = 'Stock Price')
# Out:
# <AxesSubplot:title={'center':'Stock Price'}, xlabel='Date'>
